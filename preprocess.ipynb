# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfTransformer

# %%
news = pd.read_csv('Datas\\news_final.csv')
news['Date'] = pd.to_datetime(news["Date"])
display(news)
# Out:
#                                                   Title  \
# 0     İş Bankası'ndan borçlanma aracı ihracı için SP...
# 1     Çavuşoğlu, Rus mevkidaşı ile tahıl koridorunu ...
# 2            TEB'in sendikasyonunda da maliyet yükseldi
# 3     Hazine 2023'te 10 milyar dolar dış borçlanma ö...
# 4              Şişecam'dan 3. çeyrekte hızlı performans
# ...                                                 ...
# 2613     Dolar/TL'de dikkatler ABD istihdam verilerinde
# 2614  Dünyanın en büyük emeklilik fonunda 2 yılın en...
# 2615        Rekabet Kurulu'ndan Nesine.com'a soruşturma
# 2616             TCMB'den KİT'lere döviz satışında mola
# 2617  Serbest piyasada döviz açılış fiyatları (05.08...
#
#                                             Description       Date  \
# 0     İş Bankası yurt içinde 33 milyar TL'ye kadar b... 2022-10-31
# 1     Dışişleri Bakanı Çavuşoğlu, Rus mevkidaşı Serg... 2022-10-31
# 2     TEB'in sendikasyonunda maliyetlerin yükseldiği... 2022-10-31
# 3     Hazine ve Maliye Bakanlığı'nın 2023 yılına ili... 2022-10-31
# 4     Şişecam yılın 3. çeyreğinde 4,8 milyar TL'lik ... 2022-10-31
# ...                                                 ...        ...
# 2613  Dolar/TL psikolojik eşik 18'e yakın seyrini de... 2022-08-05
# 2614  Dünyanın en büyük emeklilik fonu olan Japonya ... 2022-08-05
# 2615  Rekabet Kurulu, Nesine.com hakkında yürütülen ... 2022-08-05
# 2616  Türkiye Cumhuriyet Merkez Bankası (TCMB) 10 ay... 2022-08-05
# 2617  İstanbul serbest piyasada dolar 17,9500 lirada... 2022-08-05
#
#            Source
# 0     BloombergHT
# 1     BloombergHT
# 2     BloombergHT
# 3     BloombergHT
# 4     BloombergHT
# ...           ...
# 2613  BloombergHT
# 2614  BloombergHT
# 2615  BloombergHT
# 2616  BloombergHT
# 2617  BloombergHT
#
# [2618 rows x 4 columns]

# %%
from datetime import date, timedelta
def daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days)):
        yield start_date + timedelta(n)

# %%
start_date = date(2022, 8, 1)
end_date = date(2022, 11, 1)


display(news.where(news['Date'] < pd.to_datetime(date(2022,10,1)).floor('D') ))
# for date in daterange(start_date, end_date):
#     numOfNews = len(news.where(news['Date'] == date))
#     print(f'{numOfNews} number of news in {date}')
# Out:
# ---------------------------------------------------------------------------
# InvalidComparison                         Traceback (most recent call last)
# File c:\Users\suley\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\arrays\datetimelike.py:1054, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#    1053 try:
# -> 1054     other = self._validate_comparison_value(other)
#    1055 except InvalidComparison:
#
# File c:\Users\suley\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\arrays\datetimelike.py:588, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     587 elif not is_list_like(other):
# --> 588     raise InvalidComparison(other)
#     590 elif len(other) != len(self):
#
# InvalidComparison: 2022-10-01
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In [30], line 5
#       1 start_date = date(2022, 8, 1)
#       2 end_date = date(2022, 11, 1)
# ----> 5 display(news.where(news['Date'] < date(2022,10,1)))
#       6 # for date in daterange(start_date, end_date):
#       7 #     numOfNews = len(news.where(news['Date'] == date))
#       8 #     print(f'{numOfNews} number of news in {date}')
#
# File c:\Users\suley\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File c:\Users\suley\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\arraylike.py:50, in OpsMixin.__lt__(self, other)
#      48 @unpack_zerodim_and_defer("__lt__")
#      49 def __lt__(self, other):
# ---> 50     return self._cmp_method(other, operator.lt)
#
# File c:\Users\suley\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6242 with np.errstate(all="ignore"):
# -> 6243     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6245 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\suley\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\ops\array_ops.py:273, in comparison_op(left, right, op)
#     264         raise ValueError(
#     265             "Lengths must match to compare", lvalues.shape, rvalues.shape
#     266         )
#     268 if should_extension_dispatch(lvalues, rvalues) or (
#     269     (isinstance(rvalues, (Timedelta, BaseOffset, Timestamp)) or right is NaT)
#     270     and not is_object_dtype(lvalues.dtype)
#     271 ):
#     272     # Call the method on lvalues
# --> 273     res_values = op(lvalues, rvalues)
#     275 elif is_scalar(rvalues) and isna(rvalues):  # TODO: but not pd.NA?
#     276     # numpy does not like comparisons vs None
#     277     if op is operator.ne:
#
# File c:\Users\suley\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File c:\Users\suley\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\arraylike.py:50, in OpsMixin.__lt__(self, other)
#      48 @unpack_zerodim_and_defer("__lt__")
#      49 def __lt__(self, other):
# ---> 50     return self._cmp_method(other, operator.lt)
#
# File c:\Users\suley\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\arrays\datetimelike.py:1056, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#    1054     other = self._validate_comparison_value(other)
#    1055 except InvalidComparison:
# -> 1056     return invalid_comparison(self, other, op)
#    1058 dtype = getattr(other, "dtype", None)
#    1059 if is_object_dtype(dtype):
#    1060     # We have to use comp_method_OBJECT_ARRAY instead of numpy
#    1061     #  comparison otherwise it would fail to raise when
#    1062     #  comparing tz-aware and tz-naive
#
# File c:\Users\suley\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\ops\invalid.py:36, in invalid_comparison(left, right, op)
#      34 else:
#      35     typ = type(right).__name__
# ---> 36     raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      37 return res_values
#
# TypeError: Invalid comparison between dtype=datetime64[ns] and date
